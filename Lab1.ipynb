# %% [markdown]
# <a href="https://colab.research.google.com/github/Ansh280705/Machine-Learning/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#list creation
countries=['indai','australia','usa']

# %%
print (countries)
# Out:
# ['indai', 'australia', 'usa']

# %%
print("vlaue a i0 index",countries[0])
# Out:
# vlaue a i0 index indai

# %%
countries[0]='Germany'

# %%
print ("value 0",countries[0])
# Out:
# value 0 Germany

# %%
hybridlist=['my name is ',
            'Iam in']

# %%
for item in hybridlist:
  print (item)
# Out:
# my name is
# Iam in

# %%
countries = ['india','australia','usa']
for index,country in enumerate(countries):
  place = str(index)
  print("index"+place +",value"+country)
# Out:
# index0,valueindia
# index1,valueaustralia
# index2,valueusa

# %%
index = countries.index('India')
print (index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_535/2409866901.py in <cell line: 0>()
# ----> 1 index = countries.index('India')
#       2 print (index)
#
# ValueError: 'India' is not in list

# %%
del countries[-1]
print (countries)

# %%
#without comphresnison
cubes =[x**2]

# %%
#normal for loop
l=[1,2,3,4,4]
for i in l:
[i for i in l ]

# %%
l = [2,4,6,8,10,114]
[i**2 for i in l if i**2>50]

# %%
dict={"sedan":1500 ,"SUV":2000,"pickup":2500}
d = [i.lower() for i in dict if dict[i]<5000]
print(d)

# %%
l=[1,2,3,4,5,6,7,8,9]
l2=['high' if i>5 else 'low' for i in l]
print (l2)

# %%
l=[1,2,3,4,5,6,7,8,9]
l2=['1' if i>5 else '0' for i in l]
print (l2)

# %%
[27*x for x in range(1,21) if x**2<=10 ]

# %%
[x for x in range(51) if x%2==0 ]

# %%
[x for x in range (51) if x%2==0 and x%5==0]

# %%
obj =["Even" if i%2==0 else "odd" for i in range (10)]

# %%
string = "ilove csit department"
j=[]
for (i in ['a','e','i','o','u'])
j.append(i)

# %%
number = [3,5,45,97,32,22,10,39,43]

[number.remove(i) for i in number if i % 2 != 0]

print(number)

# %%
sentence ='In 19823 there were 13 instances of a protest with over 100'
words = sentence.split()
result=[number for number in words if not number.isalpha()]
print(result)

# %%
list_a=[1,2,3,4]
list_b=[2,3,4,5]
common = [a for a in list_a if a in list_b]
print (common)
